# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('C:/Users/Admin/Desktop/GitHub/IPL_Data_Analysis/deliveries.csv')
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# #### indepth Analysis of David Warner(Australian Batsman) Performance

# %%
filt=(df['batsman']=='DA Warner')#make a filter df where all info abt DA Warner is
df_warner=df[filt]#make a datframe of tht filter df
df_warner.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df_warner['dismissal_kind'].value_counts().plot.pie()#count various kinds of dismassal_kind(column).
#As u see almost 75% time DA Warner gets out through a catch

# %% [markdown]
# #### total fours by da warner

# %%
len(df_warner[df_warner['batsman_runs']==4])
# Out:
# 401

# %%
401*4
# Out:
# 1604

# %% [markdown]
# ##### total 6s by da warner

# %%
len(df_warner[df_warner['batsman_runs']==6])
# Out:
# 160

# %% [markdown]
# ##### total runs made by DA warner

# %%
df_warner['total_runs'].sum()
# Out:
# 4213

# %% [markdown]
# ##### pie chart of Runs contribution of David Warner

# %%
def count(df,runs):
    return len(df_warner[df_warner['batsman_runs']==runs])*runs#formula for total runs made by either 1,2,3,4,6
#eg as 401 times he hits a 4.total runs due to hitting 401*4 will be 1604

# %%
count(df_warner,1)
# Out:
# 997

# %%
count(df_warner,2)
# Out:
# 414

# %%
count(df_warner,3)
# Out:
# 39

# %%
count(df_warner,4)
# Out:
# 1604

# %%
count(df_warner,6)
# Out:
# 960

# %%
slices=[997,414,39,1604,960]#pass the count of number of runs that we found above as slices
labels=[1,2,3,4,6]#these are the runs made
explode=[0,0,0,0,0.1]#to highlight the 6th slot
plt.pie(slices,labels=labels,autopct='%1.1f%%',explode=explode)#formula to write numbers in the form of % is %1.1f%%
plt.title("DA Warner total runs contribution")
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Gujarat Lions', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Rising Pune Supergiants'], dtype=object)

# %% [markdown]
# ##### Replacing the Team Names with their abbreviations

# %%
#create a dictionary with team name and abbrievation

Teams={
    'Royal Challengers Bangalore':'RCB', 
    'Sunrisers Hyderabad':'SRH',
       'Rising Pune Supergiant':'RPS',
    'Mumbai Indians':'MI',
       'Kolkata Knight Riders':'KKR', 
    'Gujarat Lions':'GL',
    'Kings XI Punjab':'KXIP',
       'Delhi Daredevils':'DD',
    'Chennai Super Kings':'CSK',
    'Rajasthan Royals':'RR',
       'Deccan Chargers':'DC',
    'Kochi Tuskers Kerala':'KTK',
    'Pune Warriors':'PW',
       'Rising Pune Supergiants':'RPS'
}

# %%
df['batting_team']=df['batting_team'].map(Teams)#replace batting team column with abbrievation
df['bowling_team']=df['bowling_team'].map(Teams)#replace bowling team column with abbrievation

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          SRH          RCB     1     1  DA Warner
# 1         1       1          SRH          RCB     1     2  DA Warner
# 2         1       1          SRH          RCB     1     3  DA Warner
# 3         1       1          SRH          RCB     1     4  DA Warner
# 4         1       1          SRH          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %% [markdown]
# #### Score Distribution For Teams by Innings

# %%
runs=df.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()
# we calculate sum of total runs based on'match_id','inning','batting_team' respectively 
runs.head()
# Out:
#    match_id  inning batting_team  total_runs
# 0         1       1          SRH         207
# 1         1       2          RCB         172
# 2         2       1           MI         184
# 3         2       2          RPS         187
# 4         3       1           GL         183

# %%
runs.drop('match_id',axis=1,inplace=True)
#we drop match id column and using axis=1 it is applied vertically and inplace is true to update the current df
runs.head()
# Out:
#    inning batting_team  total_runs
# 0       1          SRH         207
# 1       2          RCB         172
# 2       1           MI         184
# 3       2          RPS         187
# 4       1           GL         183

# %%
inning1=runs[runs['inning']==1]#filter where inning=1 is passed in the runs df
inning2=runs[runs['inning']==2]#filter where inning=2 is passed in the runs df

# %%
sns.boxplot(x='batting_team',y='total_runs',data=inning1)

# %% [markdown]
# ##### According to this plot, the batting by CSK & RCB seems best.

# %%
sns.boxplot(x='batting_team',y='total_runs',data=inning2)

# %% [markdown]
# ##### This figure also conveys the same story.In this, we see a point near 0 for RCB which may seem to be outlier. But it is on account of  match disruption.

# %% [markdown]
# ##### how many times teams scores more than 200

# %%
high_scores=df.groupby(['match_id', 'inning','batting_team','bowling_team'])['total_runs'].sum().reset_index() 
high_scores
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 1            1       2          RCB          SRH         172
# 2            2       1           MI          RPS         184
# 3            2       2          RPS           MI         187
# 4            3       1           GL          KKR         183
# ...        ...     ...          ...          ...         ...
# 1279       634       2          KKR          SRH         140
# 1280       635       1           GL          SRH         162
# 1281       635       2          SRH           GL         163
# 1282       636       1          SRH          RCB         208
# 1283       636       2          RCB          SRH         200
#
# [1284 rows x 5 columns]

# %%
score_200=high_scores[high_scores['total_runs']>=200]
score_200
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 16           9       1           DD          RPS         205
# 38          20       1          RCB           GL         213
# 62          32       1          SRH         KXIP         207
# 72          36       1          SRH          KKR         209
# ...        ...     ...          ...          ...         ...
# 1250       620       1          RCB           GL         248
# 1256       623       1           MI           DD         206
# 1262       626       1          RCB         KXIP         211
# 1282       636       1          SRH          RCB         208
# 1283       636       2          RCB          SRH         200
#
# [67 rows x 5 columns]

# %%
plt.figure(figsize=(10,6))
sns.countplot(score_200['batting_team'])

# %%
sns.countplot(score_200['bowling_team'])

# %% [markdown]
# ##### 1st graph shows the number of times a team has scored above 200 runs. 2nd graph shows the number of times a bowling team has conceeded above 200 runs.

# %% [markdown]
# ##### how many times team scores >200 runs against batting team

# %%
high_200=df.groupby(['match_id', 'inning','batting_team','bowling_team'])['total_runs'].sum().reset_index()
high_200.set_index(['match_id'],inplace=True)

# %%
high_200['total_runs'].max()
# Out:
# 263

# %%
high_200.columns
# Out:
# Index(['inning', 'batting_team', 'bowling_team', 'total_runs'], dtype='object')

# %%
high_200.head()
# Out:
#           inning batting_team bowling_team  total_runs
# match_id
# 1              1          SRH          RCB         207
# 1              2          RCB          SRH         172
# 2              1           MI          RPS         184
# 2              2          RPS           MI         187
# 3              1           GL          KKR         183

# %%
high=high_200.rename(columns={'total_runs':'count'})
high=high[high['count']>=200].groupby(['inning','batting_team','bowling_team']).count()
high
# Out:
#                                   count
# inning batting_team bowling_team
# 1      CSK          DD                1
#                     KKR               1
#                     KXIP              2
#                     MI                1
#                     RCB               1
#                     RR                1
#                     SRH               2
#        DC           RR                1
#        DD           KXIP              1
#                     MI                1
#                     RPS               1
#        GL           DD                1
#        KKR          DC                1
#                     KXIP              1
#                     RCB               1
#        KXIP         CSK               2
#                     MI                1
#                     RCB               2
#                     RR                1
#        MI           CSK               1
#                     DD                4
# ...

# %% [markdown]
# ##### Batsman Comparison

# %%
balls=df.groupby(['batsman'])['ball'].count().reset_index()
balls
# Out:
#             batsman  ball
# 0    A Ashish Reddy   196
# 1        A Chandila     7
# 2          A Chopra    75
# 3       A Choudhary    20
# 4        A Flintoff    57
# ..              ...   ...
# 456     YV Takawale   183
# 457   Yashpal Singh    67
# 458     Younis Khan     7
# 459    Yuvraj Singh  2050
# 460          Z Khan   141
#
# [461 rows x 2 columns]

# %%
runs=df.groupby(['batsman'])['batsman_runs'].sum().reset_index()#total runs made by a batsman
runs.columns=['batsman','runs']
runs

###runs=df.groupby(['batsman'])['batsman_runs'].agg(sum).reset_index()
# Out:
#             batsman  runs
# 0    A Ashish Reddy   280
# 1        A Chandila     4
# 2          A Chopra    53
# 3       A Choudhary    25
# 4        A Flintoff    62
# ..              ...   ...
# 456     YV Takawale   192
# 457   Yashpal Singh    47
# 458     Younis Khan     3
# 459    Yuvraj Singh  2591
# 460          Z Khan   117
#
# [461 rows x 2 columns]

# %%
df.groupby(['batsman'])['batsman_runs'].agg(sum)
# Out:
# batsman
# A Ashish Reddy     280
# A Chandila           4
# A Chopra            53
# A Choudhary         25
# A Flintoff          62
#                   ...
# YV Takawale        192
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2591
# Z Khan             117
# Name: batsman_runs, Length: 461, dtype: int64

# %%
balls=balls.merge(runs,left_on='batsman',right_on='batsman',how='outer')

# %%
four=df[df['batsman_runs']==4]

# %%
''' df.groupby('batsman')['batsman_runs'].agg(lambda x: (x==4).sum()).reset_index()'''

runs_4=four.groupby('batsman')['batsman_runs'].count().reset_index()
runs_4.columns=['batsman','4s']#number of times a batsman hits 4
runs_4
# Out:
#             batsman   4s
# 0    A Ashish Reddy   16
# 1          A Chopra    7
# 2       A Choudhary    1
# 3        A Flintoff    5
# 4          A Kumble    3
# ..              ...  ...
# 363       YK Pathan  240
# 364     YV Takawale   26
# 365   Yashpal Singh    5
# 366    Yuvraj Singh  205
# 367          Z Khan   11
#
# [368 rows x 2 columns]

# %%
six=df.groupby('batsman')['batsman_runs'].agg(lambda x: (x==6).sum()).reset_index()
six.columns=['batsman','6s']#number of 6s made by a batsman
six
# Out:
#             batsman   6s
# 0    A Ashish Reddy   15
# 1        A Chandila    0
# 2          A Chopra    0
# 3       A Choudhary    1
# 4        A Flintoff    2
# ..              ...  ...
# 456     YV Takawale    3
# 457   Yashpal Singh    0
# 458     Younis Khan    0
# 459    Yuvraj Singh  141
# 460          Z Khan    2
#
# [461 rows x 2 columns]

# %%
player=pd.concat([runs,balls.iloc[:,1],runs_4.iloc[:,1],six.iloc[:,1]],axis=1)#combine all dataframes and we use axis=1 to concatenate vertically
#From balls df you select all rows but only 1st column similarly from other df as well.
player
# Out:
#             batsman  runs  ball    4s   6s
# 0    A Ashish Reddy   280   196  16.0   15
# 1        A Chandila     4     7   7.0    0
# 2          A Chopra    53    75   1.0    0
# 3       A Choudhary    25    20   5.0    1
# 4        A Flintoff    62    57   3.0    2
# ..              ...   ...   ...   ...  ...
# 456     YV Takawale   192   183   NaN    3
# 457   Yashpal Singh    47    67   NaN    0
# 458     Younis Khan     3     7   NaN    0
# 459    Yuvraj Singh  2591  2050   NaN  141
# 460          Z Khan   117   141   NaN    2
#
# [461 rows x 5 columns]

# %%
player.fillna(0,inplace=True)
player
# Out:
#             batsman  runs  ball    4s   6s
# 0    A Ashish Reddy   280   196  16.0   15
# 1        A Chandila     4     7   7.0    0
# 2          A Chopra    53    75   1.0    0
# 3       A Choudhary    25    20   5.0    1
# 4        A Flintoff    62    57   3.0    2
# ..              ...   ...   ...   ...  ...
# 456     YV Takawale   192   183   0.0    3
# 457   Yashpal Singh    47    67   0.0    0
# 458     Younis Khan     3     7   0.0    0
# 459    Yuvraj Singh  2591  2050   0.0  141
# 460          Z Khan   117   141   0.0    2
#
# [461 rows x 5 columns]

# %%
player['strike_rate']=(player['runs']/player['ball'])*100
player.head()
# Out:
#           batsman  runs  ball    4s  6s  strike_rate
# 0  A Ashish Reddy   280   196  16.0  15   142.857143
# 1      A Chandila     4     7   7.0   0    57.142857
# 2        A Chopra    53    75   1.0   0    70.666667
# 3     A Choudhary    25    20   5.0   1   125.000000
# 4      A Flintoff    62    57   3.0   2   108.771930

# %%
player.isna().sum()
# Out:
# batsman        0
# runs           0
# ball           0
# 4s             0
# 6s             0
# strike_rate    0
# dtype: int64

# %%
player['4s'].fillna(0,inplace=True)

# %%
player.isnull().values.any()
# Out:
# False

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
grp=df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index()
grp
# Out:
#       match_id       batsman batting_team  batsman_runs
# 0            1   A Choudhary          RCB             6
# 1            1   BCJ Cutting          SRH            16
# 2            1      CH Gayle          RCB            32
# 3            1     DA Warner          SRH            14
# 4            1      DJ Hooda          SRH            16
# ...        ...           ...          ...           ...
# 9510       636     SR Watson          RCB            11
# 9511       636     STR Binny          RCB             9
# 9512       636   Sachin Baby          RCB            18
# 9513       636       V Kohli          RCB            54
# 9514       636  Yuvraj Singh          SRH            38
#
# [9515 rows x 4 columns]

# %%
max=grp.groupby(['batsman'])['batsman_runs'].max().reset_index()#max runs of individual players
max.columns=['batsman','max_runs']
max
# Out:
#             batsman  max_runs
# 0    A Ashish Reddy        36
# 1        A Chandila         4
# 2          A Chopra        24
# 3       A Choudhary        15
# 4        A Flintoff        24
# ..              ...       ...
# 456     YV Takawale        45
# 457   Yashpal Singh        20
# 458     Younis Khan         3
# 459    Yuvraj Singh        83
# 460          Z Khan        23
#
# [461 rows x 2 columns]

# %%
player2=pd.concat([player,max.iloc[:,1:3]],axis=1)#to concatenate 2 df (i.e. player and max )vertically we use axis=1 and we need all rows and 2columns from max df
player2
# Out:
#             batsman  runs  ball    4s   6s  strike_rate  max_runs
# 0    A Ashish Reddy   280   196  16.0   15   142.857143        36
# 1        A Chandila     4     7   7.0    0    57.142857         4
# 2          A Chopra    53    75   1.0    0    70.666667        24
# 3       A Choudhary    25    20   5.0    1   125.000000        15
# 4        A Flintoff    62    57   3.0    2   108.771930        24
# ..              ...   ...   ...   ...  ...          ...       ...
# 456     YV Takawale   192   183   0.0    3   104.918033        45
# 457   Yashpal Singh    47    67   0.0    0    70.149254        20
# 458     Younis Khan     3     7   0.0    0    42.857143         3
# 459    Yuvraj Singh  2591  2050   0.0  141   126.390244        83
# 460          Z Khan   117   141   0.0    2    82.978723        23
#
# [461 rows x 7 columns]

# %%
player2.shape
# Out:
# (461, 7)

# %% [markdown]
# #### Top 10 Batsman

# %%
max_runs=df.groupby(['batsman'])['batsman_runs'].sum()
max_runs.sort_values(ascending=False)[:10].plot.bar()#sort batsman based on max runs for top 10 players

# %% [markdown]
# #### SK Raina has highest total runs across all seasons Whereas Virat Kohliis just few runs behind with the second spot

# %% [markdown]
# #### Top Individual Scores

# %%
df.groupby(["match_id","batsman",'batting_team'])["batsman_runs"].sum().reset_index().sort_values(by='batsman_runs', ascending=False).head(10)
# Out:
#       match_id         batsman batting_team  batsman_runs
# 6200       411        CH Gayle          RCB           175
# 900         60     BB McCullum          KKR           158
# 8426       562  AB de Villiers          RCB           133
# 9257       620  AB de Villiers          RCB           129
# 5585       372        CH Gayle          RCB           128
# 3135       206         M Vijay          CSK           127
# 529         36       DA Warner          SRH           126
# 7752       516        V Sehwag         KXIP           122
# 3686       243     PC Valthaty         KXIP           120
# 4223       279        V Sehwag           DD           119

# %% [markdown]
# #### Not only Gayle but there are many RCB players on the top scores list. Looks like RCB is a very formidable batting side.

# %% [markdown]
# ##### Highest Wicket Taker

# %%
df['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
dismissal_kinds = ['caught', 'bowled', 'lbw', 'caught and bowled',
       'stumped', 'hit wicket']

# %%
hwt=df[df["dismissal_kind"].isin(dismissal_kinds)]
hwt.head()
# Out:
#      match_id  inning batting_team bowling_team  over  ball        batsman  \
# 11          1       1          SRH          RCB     2     5      DA Warner
# 64          1       1          SRH          RCB    11     3       S Dhawan
# 94          1       1          SRH          RCB    16     2   MC Henriques
# 116         1       1          SRH          RCB    19     4   Yuvraj Singh
# 160         1       2          RCB          SRH     6     4  Mandeep Singh
#
#       non_striker       bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 11       S Dhawan  A Choudhary              0  ...         0            0
# 64   MC Henriques    STR Binny              0  ...         0            0
# 94   Yuvraj Singh    YS Chahal              0  ...         0            0
# 116      DJ Hooda     TS Mills              0  ...         0            0
# 160      CH Gayle  Rashid Khan              0  ...         0            0
#
# ...

# %%
hwt['bowler'].value_counts()[:10].plot.bar()#Top 10 wicket taking bowler

# %% [markdown]
# ##### SL Malinga leads the chart,
